# %% [markdown]
# # Data #

# %% [markdown]
# The data, which is required to analyze the preferences of hotel guests in periods of a year, is obtained from Kaggle Datasets: Hotel Booking Demand (https://www.kaggle.com/jessemostipak/hotel-booking-demand)

# %% [markdown]
# # Methodology #

# %% [markdown]
# At the beginning, the csv file obtained from Kaggle Datasets has been transformed into a pandas data frame.
# It basically looks like this:

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# Then, in order to demonstrate in which months and how many hotel rooms booked, we draw a histogram based on our dataset.

# %%
df_year.plot(kind='bar', figsize=(10, 6))
plt.title('Booking for Each Month in a Year') # add a title to the histogram
plt.ylabel('Bookings') # add y-label
plt.xlabel('Month') # add x-label
plt.show()

# %% [markdown]
# The preferences of hotels differ by hotel type such as whether it is City Hotel or Resort Hotel. At that point we need to categorize dataset in two parts: City Hotels and Resort Hotels.

# %%
df_hotel_year
# Out:
#            City Hotel  Resort Hotel
# Month
# January          3736          2193
# February         4965          3103
# March            6458          3336
# April            7480          3609
# May              8232          3559
# June             7894          3045
# July             8088          4573
# August           8983          4894
# September        7400          3108
# October          7605          3555
# November         4357          2437
# December         4132          2648

# %% [markdown]
# To examine our result in a better way we draw a histogram with our dataset

# %%
df_hotel_year.plot(kind='bar', figsize=(15, 6))


plt.title('Booking for Each Month in a Year') # add a title to the histogram
plt.ylabel('Bookings') # add y-label
plt.xlabel('Month') # add x-label

plt.show()

# %% [markdown]
# In addition, the number of nights that guests stayed at the hotel differs through months in a year. To serve in a best way, hotels have to make their guest have a beautiful experience during their stay. Predicting average number of nights of their stay might be a beneficial information.

# %%
monthly_stay
# Out:
#        Months   Average
# 0     January  2.971496
# 1    February  3.031111
# 2       March  3.419338
# 3       April  3.366850
# 4         May  3.276567
# 5        June  3.575830
# 6        July  3.925835
# 7      August  3.896880
# 8   September  3.466407
# 9     October  3.126075
# 10   November  3.189137
# 11   December  3.222566
